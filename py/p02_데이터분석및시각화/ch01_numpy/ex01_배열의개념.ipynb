# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 10.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.6 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.6 MB 11.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.5 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
